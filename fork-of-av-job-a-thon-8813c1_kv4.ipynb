# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/jobathon-analytics-vidhya/sample_submission.csv
# /kaggle/input/jobathon-analytics-vidhya/train.csv
# /kaggle/input/jobathon-analytics-vidhya/test.csv

# %%
train=pd.read_csv("/kaggle/input/jobathon-analytics-vidhya/train.csv")
test=pd.read_csv("/kaggle/input/jobathon-analytics-vidhya/test.csv")
s=pd.read_csv("/kaggle/input/jobathon-analytics-vidhya/sample_submission.csv")

# %%
train
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3         3213            Rented          Individual
# 1          2        C5         1117             Owned               Joint
# 2          3        C5         3732             Owned          Individual
# 3          4       C24         4378             Owned               Joint
# 4          5        C8         2190            Rented          Individual
# ...      ...       ...          ...               ...                 ...
# 50877  50878        C4          845            Rented          Individual
# 50878  50879        C5         4188            Rented          Individual
# 50879  50880        C1          442            Rented          Individual
# 50880  50881        C1            4             Owned               Joint
# 50881  50882        C3         3866            Rented          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# 0             36         36        No               X1
# 1             75         22        No               X2
# 2             32         32        No              NaN
# 3             52         48        No               X1
# 4             44         44        No               X2
# ...          ...        ...       ...              ...
# 50877         22         22        No               X3
# 50878         27         27        No               X3
# 50879         63         63        No               X2
# 50880         71         49        No               X2
# 50881         24         24        No               X3
#
#       Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                         14+                  3.0               22
# 1                         NaN                  NaN               22
# 2                         1.0                  1.0               19
# 3                         14+                  3.0               19
# 4                         3.0                  1.0               16
# ...                       ...                  ...              ...
# 50877                     NaN                  NaN               18
# 50878                     7.0                  3.0                4
# 50879                     14+                  1.0               12
# 50880                     2.0                  2.0               16
# 50881                     2.0                  3.0               18
#
#        Reco_Policy_Premium  Response
# 0                  11628.0         0
# 1                  30510.0         0
# 2                   7450.0         1
# 3                  17780.0         0
# 4                  10404.0         0
# ...                    ...       ...
# 50877               7704.0         0
# 50878               5408.0         0
# 50879              11374.0         0
# 50880              28179.2         1
# 50881              11424.0         0
#
# [50882 rows x 14 columns]

# %%
train[train['Health Indicator'].isnull()==True]
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 2          3        C5         3732             Owned          Individual
# 6          7        C3          679             Owned          Individual
# 9         10        C1          530             Owned               Joint
# 12        13        C7         3453             Owned          Individual
# 19        20       C20          973             Owned          Individual
# ...      ...       ...          ...               ...                 ...
# 50859  50860        C1          217             Owned          Individual
# 50865  50866       C21         4915             Owned          Individual
# 50869  50870       C11         1770            Rented          Individual
# 50871  50872       C10          224            Rented          Individual
# 50876  50877       C26          579             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# 2             32         32        No              NaN
# 6             28         28        No              NaN
# 9             59         26       Yes              NaN
# 12            66         66        No              NaN
# 19            27         27        No              NaN
# ...          ...        ...       ...              ...
# 50859         70         70        No              NaN
# 50865         74         74        No              NaN
# 50869         45         45        No              NaN
# 50871         21         21        No              NaN
# 50876         37         37        No              NaN
#
#       Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 2                         1.0                  1.0               19
# 6                         NaN                  NaN               17
# 9                         7.0                  4.0               18
# 12                        1.0                  2.0               20
# 19                        NaN                  NaN                4
# ...                       ...                  ...              ...
# 50859                     6.0                  3.0               20
# 50865                     NaN                  NaN               14
# 50869                     1.0                  1.0               20
# 50871                     1.0                  1.0               13
# 50876                     2.0                  1.0               12
#
#        Reco_Policy_Premium  Response
# 2                   7450.0         1
# 6                  10640.0         0
# 9                  21100.8         1
# 12                 17192.0         1
# 19                  8050.0         0
# ...                    ...       ...
# 50859              19448.0         0
# 50865              19944.0         0
# 50869              10944.0         0
# 50871              11840.0         0
# 50876              13222.0         0
#
# [11691 rows x 14 columns]

# %%
train.isnull().sum()
# Out:
# ID                             0
# City_Code                      0
# Region_Code                    0
# Accomodation_Type              0
# Reco_Insurance_Type            0
# Upper_Age                      0
# Lower_Age                      0
# Is_Spouse                      0
# Health Indicator           11691
# Holding_Policy_Duration    20251
# Holding_Policy_Type        20251
# Reco_Policy_Cat                0
# Reco_Policy_Premium            0
# Response                       0
# dtype: int64

# %%
train[train['Response']==1].describe(include='all')
# Out:
#                   ID City_Code   Region_Code Accomodation_Type  \
# count   12209.000000     12209  12209.000000             12209
# unique           NaN        36           NaN                 2
# top              NaN        C1           NaN             Owned
# freq             NaN      2208           NaN              6763
# mean    25576.361209       NaN   1735.629372               NaN
# std     14684.581176       NaN   1425.534461               NaN
# min         3.000000       NaN      1.000000               NaN
# 25%     12825.000000       NaN    522.000000               NaN
# 50%     25742.000000       NaN   1396.000000               NaN
# 75%     38331.000000       NaN   2671.000000               NaN
# max     50881.000000       NaN   6194.000000               NaN
#
#        Reco_Insurance_Type     Upper_Age     Lower_Age Is_Spouse  \
# count                12209  12209.000000  12209.000000     12209
# unique                   2           NaN           NaN         2
# top             Individual           NaN           NaN        No
# freq                  9640           NaN           NaN     10157
# mean                   NaN     44.941682     42.674175       NaN
# std                    NaN     17.148054     17.206959       NaN
# min                    NaN     18.000000     16.000000       NaN
# 25%                    NaN     29.000000     27.000000       NaN
# 50%                    NaN     44.000000     40.000000       NaN
# 75%                    NaN     59.000000     57.000000       NaN
# max                    NaN     75.000000     75.000000       NaN
#
#        Health Indicator Holding_Policy_Duration  Holding_Policy_Type  \
# count              9471                    7370          7370.000000
# unique                9                      15                  NaN
# top                  X1                     14+                  NaN
# freq               3176                    1087                  NaN
# mean                NaN                     NaN             2.456174
# std                 NaN                     NaN             1.025813
# min                 NaN                     NaN             1.000000
# 25%                 NaN                     NaN             1.000000
# 50%                 NaN                     NaN             3.000000
# 75%                 NaN                     NaN             3.000000
# max                 NaN                     NaN             4.000000
#
#         Reco_Policy_Cat  Reco_Policy_Premium  Response
# count      12209.000000         12209.000000   12209.0
# unique              NaN                  NaN       NaN
# top                 NaN                  NaN       NaN
# freq                NaN                  NaN       NaN
# mean          16.405275         14277.115734       1.0
# std            5.222653          6606.163683       0.0
# min            1.000000          2408.000000       1.0
# 25%           14.000000          9282.000000       1.0
# 50%           18.000000         13280.000000       1.0
# 75%           21.000000         18210.000000       1.0
# max           22.000000         42316.800000       1.0

# %%
train[train['Response']==0].describe(include='all')
# Out:
#                   ID City_Code   Region_Code Accomodation_Type  \
# count   38673.000000     38673  38673.000000             38673
# unique           NaN        36           NaN                 2
# top              NaN        C1           NaN             Owned
# freq             NaN      6765           NaN             21188
# mean    25398.924547       NaN   1731.891914               NaN
# std     14689.686126       NaN   1423.639961               NaN
# min         1.000000       NaN      1.000000               NaN
# 25%     12686.000000       NaN    523.000000               NaN
# 50%     25367.000000       NaN   1391.000000               NaN
# 75%     38100.000000       NaN   2666.000000               NaN
# max     50882.000000       NaN   6189.000000               NaN
#
#        Reco_Insurance_Type     Upper_Age     Lower_Age Is_Spouse  \
# count                38673  38673.000000  38673.000000     38673
# unique                   2           NaN           NaN         2
# top             Individual           NaN           NaN        No
# freq                 30896           NaN           NaN     32303
# mean                   NaN     44.829312     42.759289       NaN
# std                    NaN     17.361301     17.354885       NaN
# min                    NaN     18.000000     16.000000       NaN
# 25%                    NaN     28.000000     27.000000       NaN
# 50%                    NaN     44.000000     41.000000       NaN
# 75%                    NaN     59.000000     57.000000       NaN
# max                    NaN     75.000000     75.000000       NaN
#
#        Health Indicator Holding_Policy_Duration  Holding_Policy_Type  \
# count             29720                   23261         23261.000000
# unique                9                      15                  NaN
# top                  X1                     1.0                  NaN
# freq               9834                    3502                  NaN
# mean                NaN                     NaN             2.433859
# std                 NaN                     NaN             1.025921
# min                 NaN                     NaN             1.000000
# 25%                 NaN                     NaN             1.000000
# 50%                 NaN                     NaN             3.000000
# 75%                 NaN                     NaN             3.000000
# max                 NaN                     NaN             4.000000
#
#         Reco_Policy_Cat  Reco_Policy_Premium  Response
# count      38673.000000         38673.000000   38673.0
# unique              NaN                  NaN       NaN
# top                 NaN                  NaN       NaN
# freq                NaN                  NaN       NaN
# mean          14.707910         14154.537827       0.0
# std            6.602637          6584.799295       0.0
# min            1.000000          2280.000000       0.0
# 25%           11.000000          9226.000000       0.0
# 50%           17.000000         13140.000000       0.0
# 75%           20.000000         18086.400000       0.0
# max           22.000000         43350.400000       0.0

# %%
test.describe(include='all')
# Out:
#                   ID City_Code   Region_Code Accomodation_Type  \
# count   21805.000000     21805  21805.000000             21805
# unique           NaN        36           NaN                 2
# top              NaN        C1           NaN             Owned
# freq             NaN      3789           NaN             12090
# mean    61785.000000       NaN   1748.737491               NaN
# std      6294.705646       NaN   1438.358949               NaN
# min     50883.000000       NaN      1.000000               NaN
# 25%     56334.000000       NaN    535.000000               NaN
# 50%     61785.000000       NaN   1392.000000               NaN
# 75%     67236.000000       NaN   2712.000000               NaN
# max     72687.000000       NaN   6185.000000               NaN
#
#        Reco_Insurance_Type     Upper_Age     Lower_Age Is_Spouse  \
# count                21805  21805.000000  21805.000000     21805
# unique                   2           NaN           NaN         2
# top             Individual           NaN           NaN        No
# freq                 17341           NaN           NaN     18227
# mean                   NaN     44.877734     42.748085       NaN
# std                    NaN     17.254898     17.269112       NaN
# min                    NaN     18.000000     16.000000       NaN
# 25%                    NaN     28.000000     27.000000       NaN
# 50%                    NaN     44.000000     41.000000       NaN
# 75%                    NaN     59.000000     57.000000       NaN
# max                    NaN     75.000000     75.000000       NaN
#
#        Health Indicator Holding_Policy_Duration  Holding_Policy_Type  \
# count             16778                   13202         13202.000000
# unique                9                      15                  NaN
# top                  X1                     14+                  NaN
# freq               5614                    1892                  NaN
# mean                NaN                     NaN             2.440085
# std                 NaN                     NaN             1.037627
# min                 NaN                     NaN             1.000000
# 25%                 NaN                     NaN             1.000000
# 50%                 NaN                     NaN             3.000000
# 75%                 NaN                     NaN             3.000000
# max                 NaN                     NaN             4.000000
#
#         Reco_Policy_Cat  Reco_Policy_Premium
# count      21805.000000         21805.000000
# unique              NaN                  NaN
# top                 NaN                  NaN
# freq                NaN                  NaN
# mean          15.138363         14220.306581
# std            6.302805          6497.996164
# min            1.000000          2152.000000
# 25%           12.000000          9285.000000
# 50%           17.000000         13244.000000
# 75%           20.000000         18201.600000
# max           22.000000         43776.000000

# %%
import seaborn as sns
sns.scatterplot(train['Upper_Age'],train['Reco_Policy_Premium'],hue=train['Response'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Upper_Age', ylabel='Reco_Policy_Premium'>

# %%
sns.scatterplot(train['Lower_Age'],train['Reco_Policy_Premium'],hue=train['Response'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Lower_Age', ylabel='Reco_Policy_Premium'>

# %%
sns.scatterplot(train['Upper_Age'],train['Reco_Policy_Premium'],hue=train['Reco_Insurance_Type'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Upper_Age', ylabel='Reco_Policy_Premium'>

# %%
sns.scatterplot(train['Lower_Age'],train['Reco_Policy_Premium'],hue=train['Reco_Insurance_Type'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Lower_Age', ylabel='Reco_Policy_Premium'>

# %%
sns.scatterplot(train['Upper_Age'],train['Reco_Policy_Premium'],hue=train['Accomodation_Type'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Upper_Age', ylabel='Reco_Policy_Premium'>

# %%
train.groupby(['Reco_Insurance_Type'])['Response'].mean()
# Out:
# Reco_Insurance_Type
# Individual    0.237813
# Joint         0.248309
# Name: Response, dtype: float64

# %%
df=train.append(test,ignore_index=True)
df
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 0          1        C3         3213            Rented          Individual
# 1          2        C5         1117             Owned               Joint
# 2          3        C5         3732             Owned          Individual
# 3          4       C24         4378             Owned               Joint
# 4          5        C8         2190            Rented          Individual
# ...      ...       ...          ...               ...                 ...
# 72682  72683        C3         1044             Owned          Individual
# 72683  72684        C4          266             Owned          Individual
# 72684  72685       C12         2470             Owned          Individual
# 72685  72686       C10         1676            Rented          Individual
# 72686  72687        C2         3617             Owned          Individual
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# 0             36         36        No               X1
# 1             75         22        No               X2
# 2             32         32        No              NaN
# 3             52         48        No               X1
# 4             44         44        No               X2
# ...          ...        ...       ...              ...
# 72682         45         45        No               X1
# 72683         59         59        No               X5
# 72684         74         74        No               X3
# 72685         25         25        No               X4
# 72686         73         73        No               X2
#
#       Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 0                         14+                  3.0               22
# 1                         NaN                  NaN               22
# 2                         1.0                  1.0               19
# 3                         14+                  3.0               19
# 4                         3.0                  1.0               16
# ...                       ...                  ...              ...
# 72682                     4.0                  1.0               18
# 72683                     6.0                  3.0               18
# 72684                     NaN                  NaN                1
# 72685                     3.0                  1.0               19
# 72686                     14+                  2.0                3
#
#        Reco_Policy_Premium  Response
# 0                  11628.0       0.0
# 1                  30510.0       0.0
# 2                   7450.0       1.0
# 3                  17780.0       0.0
# 4                  10404.0       0.0
# ...                    ...       ...
# 72682              15884.0       NaN
# 72683              21390.0       NaN
# 72684              17836.0       NaN
# 72685              11568.0       NaN
# 72686              23040.0       NaN
#
# [72687 rows x 14 columns]

# %%
df[df['Health Indicator'].isnull()==True]
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 2          3        C5         3732             Owned          Individual
# 6          7        C3          679             Owned          Individual
# 9         10        C1          530             Owned               Joint
# 12        13        C7         3453             Owned          Individual
# 19        20       C20          973             Owned          Individual
# ...      ...       ...          ...               ...                 ...
# 72653  72654        C3          409             Owned               Joint
# 72654  72655        C1           24             Owned          Individual
# 72658  72659        C1         1848             Owned          Individual
# 72665  72666       C24         3515             Owned          Individual
# 72666  72667       C29          112            Rented               Joint
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# 2             32         32        No              NaN
# 6             28         28        No              NaN
# 9             59         26       Yes              NaN
# 12            66         66        No              NaN
# 19            27         27        No              NaN
# ...          ...        ...       ...              ...
# 72653         60         59       Yes              NaN
# 72654         27         27        No              NaN
# 72658         68         68        No              NaN
# 72665         60         60        No              NaN
# 72666         33         31        No              NaN
#
#       Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 2                         1.0                  1.0               19
# 6                         NaN                  NaN               17
# 9                         7.0                  4.0               18
# 12                        1.0                  2.0               20
# 19                        NaN                  NaN                4
# ...                       ...                  ...              ...
# 72653                    14.0                  2.0               21
# 72654                     7.0                  2.0                7
# 72658                     8.0                  3.0               16
# 72665                     NaN                  NaN               15
# 72666                     7.0                  4.0               22
#
#        Reco_Policy_Premium  Response
# 2                   7450.0       1.0
# 6                  10640.0       0.0
# 9                  21100.8       1.0
# 12                 17192.0       1.0
# 19                  8050.0       0.0
# ...                    ...       ...
# 72653              28308.0       NaN
# 72654               6010.0       NaN
# 72658              14716.0       NaN
# 72665              19488.0       NaN
# 72666               8865.0       NaN
#
# [16718 rows x 14 columns]

# %%
# df.groupby('Reco_Policy_Cat')['Health Indicator'].transform(
#     lambda grp: grp.fillna(grp.mode().iloc[0])
# )

# %%
df.isnull().sum()
# Out:
# ID                             0
# City_Code                      0
# Region_Code                    0
# Accomodation_Type              0
# Reco_Insurance_Type            0
# Upper_Age                      0
# Lower_Age                      0
# Is_Spouse                      0
# Health Indicator           16718
# Holding_Policy_Duration    28854
# Holding_Policy_Type        28854
# Reco_Policy_Cat                0
# Reco_Policy_Premium            0
# Response                   21805
# dtype: int64

# %%
df['Holding_Policy_Duration'].value_counts()
# Out:
# 1.0     6390
# 14+     6227
# 2.0     6032
# 3.0     5192
# 4.0     3976
# 5.0     3354
# 6.0     2797
# 7.0     2309
# 8.0     1885
# 9.0     1607
# 10.0    1146
# 11.0     800
# 13.0     732
# 12.0     709
# 14.0     677
# Name: Holding_Policy_Duration, dtype: int64

# %%
test.isnull().sum()
# Out:
# ID                            0
# City_Code                     0
# Region_Code                   0
# Accomodation_Type             0
# Reco_Insurance_Type           0
# Upper_Age                     0
# Lower_Age                     0
# Is_Spouse                     0
# Health Indicator           5027
# Holding_Policy_Duration    8603
# Holding_Policy_Type        8603
# Reco_Policy_Cat               0
# Reco_Policy_Premium           0
# dtype: int64

# %%
# df = impute_categorical(df,'Region_Code','Health Indicator')
# df.groupby('Health Indicator')['Holding_Policy_Duration'].isnull().sum()

# %%
df[(df['Health Indicator']=='X1') & (df['Response']==1)]
# Out:
#           ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  \
# 43        44       C24         2748             Owned          Individual
# 64        65       C25         2200            Rented          Individual
# 68        69        C2         4068             Owned          Individual
# 71        72        C3         2476            Rented          Individual
# 77        78        C1         1321             Owned          Individual
# ...      ...       ...          ...               ...                 ...
# 50624  50625       C13         2545            Rented          Individual
# 50629  50630        C9         1975             Owned          Individual
# 50676  50677       C13          176            Rented          Individual
# 50692  50693        C5         1784            Rented               Joint
# 50858  50859        C1          494            Rented               Joint
#
#        Upper_Age  Lower_Age Is_Spouse Health Indicator  \
# 43            67         67        No               X1
# 64            20         20        No               X1
# 68            23         23        No               X1
# 71            27         27        No               X1
# 77            31         31        No               X1
# ...          ...        ...       ...              ...
# 50624         20         20        No               X1
# 50629         22         22        No               X1
# 50676         23         23        No               X1
# 50692         27         26       Yes               X1
# 50858         62         29       Yes               X1
#
#       Holding_Policy_Duration  Holding_Policy_Type  Reco_Policy_Cat  \
# 43                       14.0                  2.0               17
# 64                        NaN                  NaN               21
# 68                        NaN                  NaN                3
# 71                        NaN                  NaN               21
# 77                        NaN                  NaN               19
# ...                       ...                  ...              ...
# 50624                     NaN                  NaN               12
# 50629                     NaN                  NaN               20
# 50676                     NaN                  NaN               17
# 50692                     5.0                  2.0               20
# 50858                    13.0                  3.0               18
#
#        Reco_Policy_Premium  Response
# 43                 19936.0       1.0
# 64                  6850.0       1.0
# 68                 11536.0       1.0
# 71                 11556.0       1.0
# 77                 10032.0       1.0
# ...                    ...       ...
# 50624               5630.0       1.0
# 50629               6520.0       1.0
# 50676               7584.0       1.0
# 50692              19440.0       1.0
# 50858              24323.2       1.0
#
# [3176 rows x 14 columns]

# %%
df.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  \
# 0         36        No               X1                     14+
# 1         22        No               X2                     NaN
# 2         32        No              NaN                     1.0
# 3         48        No               X1                     14+
# 4         44        No               X2                     3.0
#
#    Holding_Policy_Type  Reco_Policy_Cat  Reco_Policy_Premium  Response
# 0                  3.0               22              11628.0       0.0
# 1                  NaN               22              30510.0       0.0
# 2                  1.0               19               7450.0       1.0
# 3                  3.0               19              17780.0       0.0
# 4                  1.0               16              10404.0       0.0

# %%
df['Health_Indicator_null'] = df['Health Indicator'].apply(lambda x: 1 if x!=x else 0)
df['Holding_Policy_Duration_null'] = df['Holding_Policy_Duration'].apply(lambda x: 1 if x!=x else 0)

# %%
# df['Health Indicator']=df.groupby('age')['Health Indicator'].transform(
#     lambda grp: grp.fillna(grp.mode().iloc[0])
# )

df['Health Indicator']=df['Health Indicator'].fillna('X10')
df['Holding_Policy_Type']=df['Holding_Policy_Type'].fillna('0.0')
df['Holding_Policy_Duration']=df['Holding_Policy_Duration'].fillna('0.0')




df['age_dist']=(df['Upper_Age']-df['Lower_Age'])/df['Lower_Age']
df['age']=(df['Upper_Age']+df['Lower_Age'])/2

# df['Health Indicator']=df.groupby('age')['Health Indicator'].transform(
#     lambda grp: grp.fillna(grp.mode().iloc[0])
# )

# df['Holding_Policy_Type']=df.groupby('age')['Holding_Policy_Type'].transform(
#     lambda grp: grp.fillna(grp.mode().iloc[0])
# )

# df['Holding_Policy_Duration']=df.groupby('age')['Holding_Policy_Duration'].transform(
#     lambda grp: grp.fillna(grp.mode().iloc[0])
# )





# df['Health Indicator']=df.groupby('Reco_Policy_Cat')['Health Indicator'].transform(
#     lambda grp: grp.fillna(grp.mode().iloc[0])
# )
# df['Holding_Policy_Type']=df.groupby(['Health Indicator'])['Holding_Policy_Type'].transform(
#     lambda grp: grp.fillna(grp.mode().iloc[0])
# )
# df['Holding_Policy_Duration']=df.groupby(['Reco_Policy_Cat','Health Indicator'])['Holding_Policy_Duration'].transform(
#     lambda grp: grp.fillna(grp.mode().iloc[0])
# )
dum=['Accomodation_Type','Reco_Insurance_Type','Is_Spouse','Holding_Policy_Type']

# %%
agg_data={
    'Reco_Policy_Premium':['sum','max','min','mean'],
    'age_dist':['sum','max','min','mean'],
    'Upper_Age':['mean','max'],
    'Lower_Age':['mean','min'],
    'Health Indicator':['size','nunique'],
    'Region_Code':['size','nunique'],
    'Holding_Policy_Duration':['size','nunique'],
    'City_Code':['size','nunique'],
    
}

df1 = df.groupby(['Reco_Policy_Cat']).agg(agg_data)

df1.columns=['A_' + '_'.join(col).strip() for col in df1.columns.values]
df1.reset_index(inplace=True)
df1.head()
df=df.merge(df1,on='Reco_Policy_Cat',how='left')

# %%
agg_data={
    'Reco_Policy_Premium':['sum','max','min','mean'],
    'age_dist':['sum','max','min','mean'],
    'Upper_Age':['mean','max'],
    'Lower_Age':['mean','min'],
    'Health Indicator':['size','nunique'],
    'Holding_Policy_Duration':['size','nunique'],
    'City_Code':['size','nunique'],
    
}

df1 = df.groupby(['Region_Code','Reco_Policy_Cat']).agg(agg_data)

df1.columns=['B_' + '_'.join(col).strip() for col in df1.columns.values]
df1.reset_index(inplace=True)
df1.head()
df=df.merge(df1,on=['Region_Code','Reco_Policy_Cat'],how='left')

# %%
agg_data={
    'Reco_Policy_Premium':['sum','max','min','mean','skew'],
    'age_dist':['sum','max','min','mean'],
    'Upper_Age':['mean','max'],
    'City_Code':['size','nunique'],
    'Region_Code':['size','nunique'],
    'Lower_Age':['mean','min'],
}

df1 = df.groupby(['Reco_Policy_Cat','Holding_Policy_Duration','Health Indicator','Holding_Policy_Type']).agg(agg_data)

df1.columns=['C_' + '_'.join(col).strip() for col in df1.columns.values]
df1.reset_index(inplace=True)
df1.head()
df=df.merge(df1,on=['Reco_Policy_Cat','Holding_Policy_Duration','Health Indicator','Holding_Policy_Type'],how='left')

# %%
agg_data={
    'Reco_Policy_Premium':['sum','max','min','mean'],
    'age_dist':['sum','max','min','mean'],
    'Upper_Age':['mean','max'],
    'Lower_Age':['mean','min'],
    'Health Indicator':['size','nunique'],
    'Holding_Policy_Duration':['size','nunique'],
    'City_Code':['size','nunique'],
    
}

df1 = df.groupby(['Region_Code','Reco_Policy_Cat','Reco_Insurance_Type']).agg(agg_data)

df1.columns=['D_' + '_'.join(col).strip() for col in df1.columns.values]
df1.reset_index(inplace=True)
df1.head()
df=df.merge(df1,on=['Region_Code','Reco_Policy_Cat','Reco_Insurance_Type'],how='left')

# %%
agg_data={
    'Reco_Policy_Premium':['sum','max','min','mean'],
    'age_dist':['sum','max','min','mean'],
    'Health Indicator':['size','nunique'],
    'Upper_Age':['mean','max'],
    'Holding_Policy_Duration':['size','nunique'],
    'City_Code':['size','nunique'],
    'Lower_Age':['mean','min'],
}

df1 = df.groupby(['Region_Code','Reco_Insurance_Type']).agg(agg_data)

df1.columns=['E_' + '_'.join(col).strip() for col in df1.columns.values]
df1.reset_index(inplace=True)
df1.head()
df=df.merge(df1,on=['Region_Code','Reco_Insurance_Type'],how='left')

# %%
for k in ['City_Code','Region_Code','Health Indicator','Holding_Policy_Duration','Reco_Policy_Cat']:
    Mean_encoded_subject = df.groupby([k])['Response'].mean().to_dict() 
    df[k+'_encoded'] =  df[k].map(Mean_encoded_subject)

# %%
# agg_data={
#     'Reco_Policy_Premium':['sum','max','min','mean'],
#     'age_dist':['sum','max','min','mean'],
#     'Lower_Age':['mean','min'],
#     'Health Indicator':['size','nunique'],
#     'Holding_Policy_Duration':['size','nunique'],
#     'Region_Code':['size','nunique'],
#     'Reco_Insurance_Type':['size','nunique'],
#     'Holding_Policy_Type':['size','nunique'],
    
# }

# df1 = df.groupby(['Reco_Policy_Cat','City_Code','Upper_Age']).agg(agg_data)

# df1.columns=['F_' + '_'.join(col).strip() for col in df1.columns.values]
# df1.reset_index(inplace=True)
# df1.head()
# df=df.merge(df1,on=['Reco_Policy_Cat','City_Code','Upper_Age'],how='left')


# agg_data={
#     'Reco_Policy_Premium':['sum','max','min','mean'],
#     'age_dist':['sum','max','min','mean'],
#     'Lower_Age':['mean','min'],
#     'Health Indicator':['size','nunique'],
#     'Holding_Policy_Duration':['size','nunique'],
#     'City_Code':['size','nunique'],
#     'Holding_Policy_Type':['size','nunique'],
#     'Reco_Policy_Cat':['size','nunique'],
    
# }

# df1 = df.groupby(['Region_Code','Upper_Age','Accomodation_Type','Reco_Insurance_Type','Is_Spouse']).agg(agg_data)

# df1.columns=['G_' + '_'.join(col).strip() for col in df1.columns.values]
# df1.reset_index(inplace=True)
# df1.head()
# df=df.merge(df1,on=['Region_Code','Upper_Age','Accomodation_Type','Reco_Insurance_Type','Is_Spouse'],how='left')


# agg_data={
#     'Reco_Policy_Premium':['sum','max','min','mean'],
#     'age_dist':['sum','max','min','mean'],
#     'Lower_Age':['mean','min'],
#     'Upper_Age':['mean','max'],
#     'City_Code':['size','nunique'],
#     'Region_Code':['size','nunique'],
#     'Reco_Insurance_Type':['size','nunique'],
    
# }

# df1 = df.groupby(['Reco_Policy_Cat','Holding_Policy_Type','Health Indicator']).agg(agg_data)

# df1.columns=['H_' + '_'.join(col).strip() for col in df1.columns.values]
# df1.reset_index(inplace=True)
# df1.head()
# df=df.merge(df1,on=['Reco_Policy_Cat','Holding_Policy_Type','Health Indicator'],how='left')



# agg_data={
#     'Reco_Policy_Premium':['sum','max','min','mean'],
#     'age_dist':['sum','max','min','mean'],
#     'Lower_Age':['mean','min'],
#     'City_Code':['size','nunique'],
#     'Region_Code':['size','nunique'],
#     'Reco_Insurance_Type':['size','nunique'],
#     'Holding_Policy_Type':['size','nunique'],
    
# }

# df1 = df.groupby(['Reco_Policy_Cat','Health Indicator','Upper_Age','Holding_Policy_Duration']).agg(agg_data)

# df1.columns=['I_' + '_'.join(col).strip() for col in df1.columns.values]
# df1.reset_index(inplace=True)
# df1.head()
# df=df.merge(df1,on=['Reco_Policy_Cat','Health Indicator','Upper_Age','Holding_Policy_Duration'],how='left')



# agg_data={
#     'Reco_Policy_Premium':['sum','max','min','mean'],
#     'age_dist':['sum','max','min','mean'],
#     'Lower_Age':['mean','min'],
#     'Upper_Age':['mean','max'],
#     'City_Code':['size','nunique'],
#     'Reco_Insurance_Type':['size','nunique'],
#     'Health Indicator':['size','nunique'],
#     'Reco_Policy_Cat':['size','nunique'],
# }

# df1 = df.groupby(['Region_Code','Holding_Policy_Duration','Holding_Policy_Type']).agg(agg_data)

# df1.columns=['J_' + '_'.join(col).strip() for col in df1.columns.values]
# df1.reset_index(inplace=True)
# df1.head()
# df=df.merge(df1,on=['Region_Code','Holding_Policy_Duration','Holding_Policy_Type'],how='left')

# %%
# agg_data={
#     'Reco_Policy_Premium':['sum','max','min','mean'],
#     'age_dist':['sum','max','min','mean'],
#     'Health Indicator':['size','nunique'],
#     'Holding_Policy_Duration':['size','nunique'],
#     'City_Code':['size','nunique'],
#     'Lower_Age':['mean','min'],
#     'Reco_Insurance_Type':['size','nunique'],
# }

# df1 = df.groupby(['Region_Code','Upper_Age']).agg(agg_data)

# df1.columns=['F_' + '_'.join(col).strip() for col in df1.columns.values]
# df1.reset_index(inplace=True)
# df1.head()
# df=df.merge(df1,on=['Region_Code','Upper_Age'],how='left')

# %%
df.head()
# Out:
#    ID City_Code  Region_Code Accomodation_Type Reco_Insurance_Type  Upper_Age  \
# 0   1        C3         3213            Rented          Individual         36
# 1   2        C5         1117             Owned               Joint         75
# 2   3        C5         3732             Owned          Individual         32
# 3   4       C24         4378             Owned               Joint         52
# 4   5        C8         2190            Rented          Individual         44
#
#    Lower_Age Is_Spouse Health Indicator Holding_Policy_Duration  ...  \
# 0         36        No               X1                     14+  ...
# 1         22        No               X2                     0.0  ...
# 2         32        No              X10                     1.0  ...
# 3         48        No               X1                     14+  ...
# 4         44        No               X2                     3.0  ...
#
#   E_Holding_Policy_Duration_nunique  E_City_Code_size  E_City_Code_nunique  \
# 0                                 3                 9                    1
# 1                                 5                10                    1
# 2                                 5                 7                    1
# 3                                 1                 1                    1
# 4                                 5                 8                    1
#
#    E_Lower_Age_mean  E_Lower_Age_min  City_Code_encoded  Region_Code_encoded  \
# 0         38.333333               24           0.237472             0.125000
# 1         33.900000               19           0.230205             0.294118
# 2         35.857143               23           0.230205             0.142857
# 3         48.000000               48           0.235081             0.400000
# 4         53.750000               28           0.241971             0.090909
#
#    Health Indicator_encoded  Holding_Policy_Duration_encoded  \
# 0                  0.244120                         0.250750
# 1                  0.241096                         0.238951
# 2                  0.234197                         0.221605
# 3                  0.244120                         0.250750
# 4                  0.241096                         0.232013
#
#    Reco_Policy_Cat_encoded
# 0                 0.328385
# 1                 0.328385
# 2                 0.276969
# 3                 0.276969
# 4                 0.223555
#
# [5 rows x 114 columns]

# %%
df['F1'] = (df['Health Indicator'].astype(str)+' '+df['Holding_Policy_Duration'].astype(str)).astype('category')
df['F2'] = (df['Health Indicator'].astype(str)+' '+df['Holding_Policy_Type'].astype(str)).astype('category')
df['F3'] = (df['Health Indicator'].astype(str)+' '+df['Reco_Policy_Cat'].astype(str)).astype('category')
df['F4'] = (df['Health Indicator'].astype(str)+' '+df['Region_Code'].astype(str)).astype('category')

df['F5'] = (df['Holding_Policy_Duration'].astype(str)+' '+df['Holding_Policy_Type'].astype(str)).astype('category')
df['F6'] = (df['Holding_Policy_Duration'].astype(str)+' '+df['Reco_Policy_Cat'].astype(str)).astype('category')
df['F7'] = (df['Holding_Policy_Duration'].astype(str)+' '+df['Region_Code'].astype(str)).astype('category')


df['F8'] = (df['Holding_Policy_Type'].astype(str)+' '+df['Reco_Policy_Cat'].astype(str)).astype('category')
df['F9'] = (df['Holding_Policy_Type'].astype(str)+' '+df['Region_Code'].astype(str)).astype('category')


df['F10'] = (df['Region_Code'].astype(str)+' '+df['Reco_Policy_Cat'].astype(str)).astype('category')



df=pd.get_dummies(df,columns=dum,drop_first=True)
cat=['City_Code','Region_Code','Health Indicator','Holding_Policy_Duration','Reco_Policy_Cat']
for k in cat:
    df[k]=df[k].astype('category')

# %%
# agg_data={
#     'Reco_Policy_Premium':['sum','max','min','mean'],
#     'age_dist':['sum','max','min','mean'],
#     'Upper_Age':['mean','max'],
#     'Lower_Age':['mean','min'],
#     'City_Code':['size','nunique'],
#     'Holding_Policy_Duration':['size','nunique'],
#     'Region_Code':['size','nunique'],
#     'Health Indicator':['size','nunique']
    
# }

# df1 = df.groupby(['Reco_Policy_Cat','Holding_Policy_Type']).agg(agg_data)

# df1.columns=['C_' + '_'.join(col).strip() for col in df1.columns.values]
# df1.reset_index(inplace=True)
# df1.head()
# df=df.merge(df1,on=['Reco_Policy_Cat','Holding_Policy_Type'],how='left')

# %%
to_drop=[]
corr_matrix = df.drop(['ID','Response'],axis=1).corr()
# print(corr_matrix)
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper   

to_drop = [column for column in upper.columns if any(upper[column] > 0.93)]
print(to_drop)
# Out:
# ['age', 'A_age_dist_sum', 'A_Lower_Age_mean', 'A_Health Indicator_size', 'A_Region_Code_size', 'A_Region_Code_nunique', 'A_Holding_Policy_Duration_size', 'A_City_Code_size', 'B_Health Indicator_size', 'B_Holding_Policy_Duration_size', 'B_City_Code_size', 'C_age_dist_sum', 'C_City_Code_size', 'C_Region_Code_size', 'C_Region_Code_nunique', 'C_Lower_Age_mean', 'D_Reco_Policy_Premium_sum', 'D_Health Indicator_size', 'D_Holding_Policy_Duration_size', 'D_City_Code_size', 'E_Health Indicator_size', 'E_Holding_Policy_Duration_size', 'E_City_Code_size', 'Holding_Policy_Type_0.0']

# %%
df.drop(to_drop,inplace=True,axis=1)

# %%
# df['Region_Code']=df['Region_Code'].astype('int')

# %%
dftrain=df[df['Response'].isnull()!=True]
dftest=df[df['Response'].isnull()==True]
dftest.head()
# Out:
#           ID City_Code Region_Code  Upper_Age  Lower_Age Health Indicator  \
# 50882  50883        C1         156         30         30              X10
# 50883  50884        C4           7         69         68               X1
# 50884  50885        C1         564         28         28               X3
# 50885  50886        C3        1177         23         23               X3
# 50886  50887        C1         951         75         75               X3
#
#       Holding_Policy_Duration Reco_Policy_Cat  Reco_Policy_Premium  Response  \
# 50882                     6.0               5              11934.0       NaN
# 50883                     3.0              18              32204.8       NaN
# 50884                     2.0              17               9240.0       NaN
# 50885                     3.0              18               9086.0       NaN
# 50886                     0.0               5              22534.0       NaN
#
#        ...        F7      F8        F9      F10  Accomodation_Type_Rented  \
# 50882  ...   6.0 156   3.0 5   3.0 156    156 5                         0
# 50883  ...     3.0 7  3.0 18     3.0 7     7 18                         0
# 50884  ...   2.0 564  4.0 17   4.0 564   564 17                         1
# 50885  ...  3.0 1177  3.0 18  3.0 1177  1177 18                         1
# 50886  ...   0.0 951   0.0 5   0.0 951    951 5                         0
#
#        Reco_Insurance_Type_Joint  Is_Spouse_Yes  Holding_Policy_Type_2.0  \
# 50882                          0              0                        0
# 50883                          1              1                        0
# 50884                          0              0                        0
# 50885                          0              0                        0
# 50886                          0              0                        0
#
#        Holding_Policy_Type_3.0  Holding_Policy_Type_4.0
# 50882                        1                        0
# 50883                        1                        0
# 50884                        0                        1
# 50885                        1                        0
# 50886                        0                        0
#
# [5 rows x 103 columns]

# %%
X,y=dftrain.drop(['ID','Response'],axis=1),dftrain['Response']
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score
X_train,X_val,y_train,y_val = train_test_split(X,y,test_size=0.25,random_state = 1994,stratify=y)

# %%
from catboost import CatBoostClassifier,Pool, cv
from lightgbm import LGBMClassifier,LGBMRegressor
from sklearn.model_selection import StratifiedKFold,train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,roc_auc_score,f1_score,mean_squared_error
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt


from sklearn.metrics import f1_score
def evaluate_exRmse_lgb(truth, predictions):  
    ex = np.exp(-np.sqrt(mean_squared_error(truth,predictions)))
    return ('EXRMSE', ex, True) 



m=LGBMClassifier(n_estimators=5000,random_state=1994,learning_rate=0.05,colsample_bytree=0.5,reg_alpha=4,min_split_gain=0.2,min_child_samples=2,bagging_fraction=0.9,max_depth=-1, )
# m=RidgeCV(cv=4)
m.fit(X_train,y_train,eval_set=[(X_val, y_val)],eval_metric='AUC', early_stopping_rounds=200,verbose=200)
p=m.predict_proba(X_val)[:,-1]
print(roc_auc_score(y_val,p))
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1286: UserWarning: Overriding the parameters from Reference Dataset.
#   warnings.warn('Overriding the parameters from Reference Dataset.')
# /opt/conda/lib/python3.7/site-packages/lightgbm/basic.py:1098: UserWarning: categorical_column in param dict is overridden.
#   warnings.warn('{} in param dict is overridden.'.format(cat_alias))
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's auc: 0.823723	valid_0's binary_logloss: 0.423922
# Early stopping, best iteration is:
# [54]	valid_0's auc: 0.833156	valid_0's binary_logloss: 0.415127
# 0.8331563412112619

# %%
import shap
shap.initjs()

shap_values = shap.TreeExplainer(m.booster_).shap_values(X_train)

shap.summary_plot(shap_values, X_train)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray

# %%
shap_sum = np.abs(shap_values).mean(axis=0).mean(axis=0)
importance_df = pd.DataFrame([X.columns.tolist(), shap_sum.tolist()]).T
importance_df.columns = ['column_name', 'shap_importance']
importance_df = importance_df.sort_values('shap_importance', ascending=False)
importance_df
# Out:
#                            column_name shap_importance
# 81                 Region_Code_encoded        0.421476
# 24           B_Reco_Policy_Premium_sum        0.399706
# 36          B_Health Indicator_nunique        0.188914
# 92                                  F8        0.146545
# 37   B_Holding_Policy_Duration_nunique        0.132659
# ..                                 ...             ...
# 46                     C_age_dist_mean        0.000000
# 55                      D_age_dist_max        0.000000
# 57                     D_age_dist_mean        0.000000
# 59                     D_Upper_Age_max        0.000000
# 100            Holding_Policy_Type_4.0        0.000000
#
# [101 rows x 2 columns]

# %%
feat_cols1= importance_df['column_name'].values[:100]

# %%
X,y=dftrain.drop(['ID','Response'],axis=1),dftrain['Response']
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score
X_train,X_val,y_train,y_val = train_test_split(X[feat_cols1],y,test_size=0.25,random_state = 1994,stratify=y)



m=LGBMClassifier(n_estimators=5000,random_state=1994,learning_rate=0.05,colsample_bytree=0.5,reg_alpha=4,min_split_gain=0.2,min_child_samples=2,bagging_fraction=0.9,max_depth=-1, )
# m=RidgeCV(cv=4)
m.fit(X_train,y_train,eval_set=[(X_val, y_val)],eval_metric='AUC', early_stopping_rounds=200,verbose=200)
p=m.predict_proba(X_val)[:,-1]
print(roc_auc_score(y_val,p))
# Out:
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# Overriding the parameters from Reference Dataset.
# categorical_column in param dict is overridden.
# Training until validation scores don't improve for 200 rounds
# [200]	valid_0's auc: 0.82326	valid_0's binary_logloss: 0.424168
# Early stopping, best iteration is:
# [64]	valid_0's auc: 0.832786	valid_0's binary_logloss: 0.413794
# 0.8327864978223496

# %%
X,y=dftrain.drop(['ID','Response'],axis=1),dftrain['Response']
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score
X_train,X_val,y_train,y_val = train_test_split(X,y,test_size=0.25,random_state = 1994,stratify=y)

from catboost import CatBoostRegressor,CatBoostClassifier
categorical_features_indices = np.where(X_train.dtypes =='category')[0]
categorical_features_indices
m2=CatBoostClassifier(n_estimators=3000,random_state=1994,eval_metric='AUC',learning_rate=0.05,random_strength=200,bagging_temperature=0.6,l2_leaf_reg=4,one_hot_max_size=10)
m2.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_val, y_val)], early_stopping_rounds=100,verbose=200,cat_features=categorical_features_indices)
p=m2.predict_proba(X_val)[:,-1]
print(roc_auc_score(y_val,p))
# Out:
# 0:	test: 0.5321396	test1: 0.5287842	best: 0.5287842 (0)	total: 225ms	remaining: 11m 15s
# 200:	test: 0.8656310	test1: 0.8008953	best: 0.8009910 (198)	total: 25.5s	remaining: 5m 55s
# 400:	test: 0.8870846	test1: 0.8775482	best: 0.8775482 (400)	total: 52.2s	remaining: 5m 38s
# 600:	test: 0.8967515	test1: 0.8831777	best: 0.8831872 (598)	total: 1m 21s	remaining: 5m 24s
# 800:	test: 0.9030352	test1: 0.8849812	best: 0.8850221 (774)	total: 1m 50s	remaining: 5m 4s
# 1000:	test: 0.9060651	test1: 0.8859154	best: 0.8859787 (967)	total: 2m 19s	remaining: 4m 39s
# 1200:	test: 0.9076499	test1: 0.8866338	best: 0.8866487 (1162)	total: 2m 49s	remaining: 4m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8867196877
# bestIteration = 1221
#
# Shrink model to first 1222 iterations.
# 0.8867196877185292

# %%
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
sns.set_style('darkgrid')
warnings.filterwarnings('ignore')

# %matplotlib inline
feature_imp = pd.DataFrame(sorted(zip(m.feature_importances_, X.columns), reverse=True)[:200], 
                           columns=['Value','Feature'])
plt.figure(figsize=(12,8))
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
plt.title('LightGBM Features')
plt.tight_layout()
plt.show()

# %%
# print(feature_imp.shape)
# feat_cols = feature_imp['Feature'][:50].values
# feat_cols

import shap
shap.initjs()

shap_values = shap.TreeExplainer(m2).shap_values(X)

shap.summary_plot(shap_values, X)


shap_sum = np.abs(shap_values).mean(axis=0)
importance_df = pd.DataFrame([X.columns.tolist(), shap_sum.tolist()]).T
importance_df.columns = ['column_name', 'shap_importance']
importance_df = importance_df.sort_values('shap_importance', ascending=False)
importance_df
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
#                           column_name shap_importance
# 81                Region_Code_encoded        0.987987
# 1                         Region_Code        0.474240
# 94                                F10        0.300465
# 24          B_Reco_Policy_Premium_sum        0.274006
# 92                                 F8        0.164268
# ..                                ...             ...
# 19                    A_Upper_Age_max        0.000000
# 22  A_Holding_Policy_Duration_nunique        0.000000
# 38                B_City_Code_nunique        0.000000
# 64                D_City_Code_nunique        0.000000
# 20                    A_Lower_Age_min        0.000000
#
# [101 rows x 2 columns]

# %%
feat_cols= importance_df['column_name'].values[:100]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

fpr, tpr, thresholds = roc_curve(y_val, p)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
X,y=dftrain.drop(['ID','Response'],axis=1),dftrain['Response']
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,f1_score
X_train,X_val,y_train,y_val = train_test_split(X[feat_cols],y,test_size=0.25,random_state = 1994,stratify=y)

from catboost import CatBoostRegressor,CatBoostClassifier
categorical_features_indices = np.where(X_train.dtypes =='category')[0]
categorical_features_indices
m2=CatBoostClassifier(n_estimators=3000,random_state=1994,eval_metric='AUC',learning_rate=0.05,random_strength=200,bagging_temperature=0.6,l2_leaf_reg=4,one_hot_max_size=10)
m2.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_val, y_val)], early_stopping_rounds=100,verbose=200,cat_features=categorical_features_indices)
p=m2.predict_proba(X_val)[:,-1]
print(roc_auc_score(y_val,p))
# Out:
# 0:	test: 0.5850221	test1: 0.5723156	best: 0.5723156 (0)	total: 153ms	remaining: 7m 38s
# 200:	test: 0.9021000	test1: 0.8080838	best: 0.8082013 (195)	total: 25.3s	remaining: 5m 52s
# 400:	test: 0.8929315	test1: 0.8770608	best: 0.8770685 (397)	total: 53.3s	remaining: 5m 45s
# 600:	test: 0.8982614	test1: 0.8826333	best: 0.8826435 (598)	total: 1m 22s	remaining: 5m 29s
# 800:	test: 0.9048673	test1: 0.8844328	best: 0.8845179 (778)	total: 1m 51s	remaining: 5m 6s
# 1000:	test: 0.9059293	test1: 0.8857395	best: 0.8857395 (1000)	total: 2m 21s	remaining: 4m 42s
# 1200:	test: 0.9040623	test1: 0.8862420	best: 0.8863012 (1196)	total: 2m 50s	remaining: 4m 15s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8866645535
# bestIteration = 1264
#
# Shrink model to first 1265 iterations.
# 0.8866645534695132

# %%
# X,y=dftrain.drop(['ID','Response'],axis=1),dftrain['Response']
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score,f1_score

# X=pd.get_dummies(X,columns=['City_Code','Health Indicator','Holding_Policy_Duration','Reco_Policy_Cat'],drop_first=True)
# X['Region_Code']=X['Region_Code'].astype(int)


# X_train,X_val,y_train,y_val = train_test_split(X,y,test_size=0.25,random_state = 1994,stratify=y)

# %%
# from tensorflow.keras import optimizers
# from tensorflow.keras import models,layers
# # from keras.models import Sequential
# # from keras.layers import Activation, Dense, Dropout
# # from keras import optimizers
# from keras.wrappers.scikit_learn import KerasClassifier
# from sklearn.model_selection import StratifiedKFold
# from sklearn.model_selection import cross_val_score
# from sklearn.preprocessing import LabelEncoder
# from sklearn.preprocessing import StandardScaler
# from sklearn.pipeline import Pipeline

# from sklearn.metrics import confusion_matrix,accuracy_score, roc_curve, auc
# %matplotlib inline
# sns.set_style("whitegrid")
# np.random.seed(697)



# def create_baseline():
#     # create model
#     model = Sequential()
#     model.add(Dense(10, input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))
#     model.add(Dense(1, kernel_initializer='normal', activation='sigmoid'))
#     # Compile model. We use the the logarithmic loss function, and the Adam gradient optimizer.
#     model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy','AUC'])
#     return model


# # Evaluate model using standardized dataset. 
# estimators = []
# # estimators.append(('standardize', StandardScaler()))
# estimators.append(('mlp', KerasClassifier(build_fn=create_baseline, epochs=100, batch_size=32, verbose=10)))
# pipeline = Pipeline(estimators)
# kfold = StratifiedKFold(n_splits=10, shuffle=True)
# results = cross_val_score(pipeline, X, y, cv=kfold)
# print("Results: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))




# # #-------------------Build the Neural Network model-------------------
# # print('Building Neural Network model...')
# # adam = optimizers.Adam(lr = 0.005, decay = 0.0000001)

# # model = Sequential()
# # model.add(Dense(100, input_dim=X_train.shape[1],
# #                 kernel_initializer='normal',
# #                 #kernel_regularizer=regularizers.l2(0.02),
# #                 activation="relu"))
# # model.add(Dropout(0.2))
# # model.add(Dense(50,
# #                 #kernel_regularizer=regularizers.l2(0.02),
# #                 activation="tanh"))
# # model.add(Dropout(0.3))
# # model.add(Dense(1))
# # model.add(Activation("sigmoid"))
# # model.compile(loss="binary_crossentropy", optimizer='adam',metrics=['AUC','acc'])

# # history = model.fit(X,y, validation_split=0.25, epochs=10, batch_size=32)

# %%
# y_pred_keras = model.predict_proba(X_val).ravel()
# print(y_pred_keras)
# fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_val, y_pred_keras)
# from sklearn.metrics import auc
# auc_keras = auc(fpr_keras, tpr_keras)
# auc_keras

# %%
feat_cols,feat_cols1
# Out:
# (array(['Region_Code_encoded', 'Region_Code', 'F10',
#         'B_Reco_Policy_Premium_sum', 'F8', 'E_Reco_Policy_Premium_sum',
#         'B_Health Indicator_nunique', 'Reco_Policy_Cat',
#         'B_Holding_Policy_Duration_nunique', 'D_Health Indicator_nunique',
#         'A_Reco_Policy_Premium_max', 'B_Reco_Policy_Premium_min',
#         'City_Code', 'D_Holding_Policy_Duration_nunique',
#         'Reco_Policy_Cat_encoded', 'F3', 'A_Reco_Policy_Premium_min',
#         'B_age_dist_sum', 'E_Holding_Policy_Duration_nunique', 'F6', 'F2',
#         'B_Reco_Policy_Premium_mean', 'D_Reco_Policy_Premium_max', 'F9',
#         'B_Lower_Age_min', 'F4', 'E_Health Indicator_nunique',
#         'D_Upper_Age_max', 'City_Code_encoded',
#         'A_Reco_Policy_Premium_mean', 'C_Reco_Policy_Premium_skew',
#         'D_Reco_Policy_Premium_mean', 'Holding_Policy_Duration',
#         'B_age_dist_max', 'E_Reco_Policy_Premium_max', 'E_Lower_Age_mean',
#         'A_age_dist_mean', 'A_age_dist_max', 'F7',
#         'C_Reco_Policy_Premium_mean', 'B_age_dist_mean',
#         'E_Reco_Policy_Premium_min', 'E_Upper_Age_mean', 'F1',
#         'A_City_Code_nunique', 'C_Reco_Policy_Premium_sum',
#         'C_age_dist_max', 'B_Upper_Age_mean', 'A_Upper_Age_mean', 'F5',
#         'A_Reco_Policy_Premium_sum', 'B_Upper_Age_max',
#         'B_Reco_Policy_Premium_max', 'E_Upper_Age_max',
#         'E_Reco_Policy_Premium_mean', 'C_Reco_Policy_Premium_max',
#         'C_age_dist_mean', 'Upper_Age', 'Reco_Policy_Premium',
#         'C_Reco_Policy_Premium_min', 'D_age_dist_min', 'C_Upper_Age_mean',
#         'Accomodation_Type_Rented', 'Holding_Policy_Duration_encoded',
#         'E_Lower_Age_min', 'Health Indicator_encoded', 'Lower_Age',
#         'E_age_dist_sum', 'D_Reco_Policy_Premium_min', 'D_Lower_Age_min',
#         'E_age_dist_max', 'D_age_dist_sum', 'C_Upper_Age_max',
#         'D_Upper_Age_mean', 'B_Lower_Age_mean', 'D_Lower_Age_mean',
#         'C_City_Code_nunique', 'C_Lower_Age_min', 'E_age_dist_min',
#         'D_age_dist_mean', 'B_age_dist_min', 'age_dist', 'E_age_dist_mean',
#         'Holding_Policy_Type_4.0', 'Health Indicator',
#         'Holding_Policy_Duration_null', 'D_age_dist_max', 'Is_Spouse_Yes',
#         'A_Health Indicator_nunique', 'Holding_Policy_Type_3.0',
#         'C_age_dist_min', 'Holding_Policy_Type_2.0',
#         'Reco_Insurance_Type_Joint', 'Health_Indicator_null',
#         'E_City_Code_nunique', 'A_age_dist_min', 'A_Upper_Age_max',
#         'A_Holding_Policy_Duration_nunique', 'B_City_Code_nunique',
#         'D_City_Code_nunique'], dtype=object),
#  array(['Region_Code_encoded', 'B_Reco_Policy_Premium_sum',
#         'B_Health Indicator_nunique', 'F8',
#         'B_Holding_Policy_Duration_nunique', 'F3',
#         'D_Holding_Policy_Duration_nunique', 'F6', 'Region_Code',
#         'E_Reco_Policy_Premium_sum', 'Reco_Policy_Cat',
#         'Reco_Policy_Cat_encoded', 'D_Health Indicator_nunique',
#         'E_Holding_Policy_Duration_nunique', 'F1', 'F10',
#         'B_Reco_Policy_Premium_min', 'C_Reco_Policy_Premium_sum',
#         'B_Lower_Age_min', 'City_Code', 'E_Health Indicator_nunique', 'F5',
#         'A_Reco_Policy_Premium_sum', 'F9', 'E_Reco_Policy_Premium_max',
#         'B_age_dist_sum', 'A_Reco_Policy_Premium_max',
#         'D_Reco_Policy_Premium_min', 'C_Reco_Policy_Premium_max',
#         'D_Reco_Policy_Premium_mean', 'F2', 'B_Reco_Policy_Premium_max',
#         'B_Upper_Age_max', 'B_Reco_Policy_Premium_mean', 'E_Upper_Age_max',
#         'A_age_dist_max', 'C_Upper_Age_max', 'A_Reco_Policy_Premium_min',
#         'A_Upper_Age_mean', 'C_age_dist_max', 'C_City_Code_nunique',
#         'D_age_dist_sum', 'D_Lower_Age_mean', 'E_age_dist_sum', 'F7',
#         'Upper_Age', 'A_age_dist_mean', 'E_Reco_Policy_Premium_mean',
#         'C_Reco_Policy_Premium_min', 'E_Lower_Age_min', 'E_age_dist_min',
#         'D_Lower_Age_min', 'A_Reco_Policy_Premium_mean', 'D_age_dist_min',
#         'D_Reco_Policy_Premium_max', 'E_Reco_Policy_Premium_min',
#         'Accomodation_Type_Rented', 'B_Upper_Age_mean', 'E_age_dist_max',
#         'E_Lower_Age_mean', 'D_Upper_Age_mean', 'F4', 'B_age_dist_mean',
#         'City_Code_encoded', 'Reco_Policy_Premium', 'C_Upper_Age_mean',
#         'B_Lower_Age_mean', 'E_age_dist_mean', 'Holding_Policy_Type_2.0',
#         'Holding_Policy_Type_3.0', 'Is_Spouse_Yes',
#         'Health Indicator_encoded', 'Holding_Policy_Duration_encoded',
#         'Reco_Insurance_Type_Joint', 'E_City_Code_nunique',
#         'C_Lower_Age_min', 'E_Upper_Age_mean',
#         'A_Holding_Policy_Duration_nunique', 'Lower_Age',
#         'Health Indicator', 'Holding_Policy_Duration',
#         'Health_Indicator_null', 'Holding_Policy_Duration_null',
#         'age_dist', 'A_age_dist_min', 'A_Upper_Age_max', 'A_Lower_Age_min',
#         'A_Health Indicator_nunique', 'A_City_Code_nunique',
#         'D_City_Code_nunique', 'B_age_dist_max', 'B_age_dist_min',
#         'B_City_Code_nunique', 'C_Reco_Policy_Premium_mean',
#         'C_Reco_Policy_Premium_skew', 'C_age_dist_min', 'C_age_dist_mean',
#         'D_age_dist_max', 'D_age_dist_mean', 'D_Upper_Age_max'],
#        dtype=object))

# %%
Xtest=dftest.drop(['ID','Response'],axis=1)
Xtest[feat_cols]
# Out:
#        Region_Code_encoded Region_Code      F10  B_Reco_Policy_Premium_sum  \
# 50882             0.379310         156    156 5                   459151.0
# 50883             0.218750           7     7 18                   697025.0
# 50884             0.105263         564   564 17                    28348.0
# 50885             0.235294        1177  1177 18                   210721.6
# 50886             0.384615         951    951 5                   289398.4
# ...                    ...         ...      ...                        ...
# 72682             0.266667        1044  1044 18                   211024.0
# 72683             0.363636         266   266 18                   386219.8
# 72684             0.200000        2470   2470 1                    87476.0
# 72685             0.333333        1676  1676 19                    19776.0
# 72686             0.200000        3617   3617 3                    50256.0
#
#            F8  E_Reco_Policy_Premium_sum  B_Health Indicator_nunique  \
# 50882   3.0 5                   503078.0                           8
# 50883  3.0 18                   279640.0                           7
# 50884  4.0 17                   348182.0                           2
# 50885  3.0 18                   161640.0                           7
# 50886   0.0 5                   285916.0                           5
# ...       ...                        ...                         ...
# 72682  1.0 18                   264078.0                           6
# 72683  3.0 18                   414652.0                           6
# 72684   0.0 1                   166834.0                           4
# 72685  1.0 19                   203142.0                           2
# 72686   2.0 3                    97894.0                           2
#
#       Reco_Policy_Cat  B_Holding_Policy_Duration_nunique  \
# 50882               5                                  9
# 50883              18                                 10
# 50884              17                                  1
# 50885              18                                  8
# 50886               5                                 10
# ...               ...                                ...
# 72682              18                                  6
# 72683              18                                 11
# 72684               1                                  3
# 72685              19                                  2
# 72686               3                                  3
#
#        D_Health Indicator_nunique  ...  C_age_dist_min  \
# 50882                           6  ...             0.0
# 50883                           2  ...             0.0
# 50884                           2  ...             0.0
# 50885                           6  ...             0.0
# 50886                           5  ...             0.0
# ...                           ...  ...             ...
# 72682                           6  ...             0.0
# 72683                           6  ...             0.0
# 72684                           3  ...             0.0
# 72685                           2  ...             0.0
# 72686                           2  ...             0.0
#
#        Holding_Policy_Type_2.0 Reco_Insurance_Type_Joint  \
# 50882                        0                         0
# 50883                        0                         1
# 50884                        0                         0
# 50885                        0                         0
# 50886                        0                         0
# ...                        ...                       ...
# 72682                        0                         0
# 72683                        0                         0
# 72684                        0                         0
# 72685                        0                         0
# 72686                        1                         0
#
#        Health_Indicator_null  E_City_Code_nunique A_age_dist_min  \
# 50882                      1                    1            0.0
# 50883                      0                    1            0.0
# 50884                      0                    1            0.0
# 50885                      0                    1            0.0
# 50886                      0                    1            0.0
# ...                      ...                  ...            ...
# 72682                      0                    1            0.0
# 72683                      0                    1            0.0
# 72684                      0                    1            0.0
# 72685                      0                    1            0.0
# 72686                      0                    1            0.0
#
#        A_Upper_Age_max  A_Holding_Policy_Duration_nunique  \
# 50882               75                                 16
# 50883               75                                 16
# 50884               75                                 16
# 50885               75                                 16
# 50886               75                                 16
# ...                ...                                ...
# 72682               75                                 16
# 72683               75                                 16
# 72684               75                                 16
# 72685               75                                 16
# 72686               75                                 16
#
#        B_City_Code_nunique D_City_Code_nunique
# 50882                    1                   1
# 50883                    1                   1
# 50884                    1                   1
# 50885                    1                   1
# 50886                    1                   1
# ...                    ...                 ...
# 72682                    1                   1
# 72683                    1                   1
# 72684                    1                   1
# 72685                    1                   1
# 72686                    1                   1
#
# [21805 rows x 100 columns]

# %%
categorical_features_indices = np.where(X[feat_cols].dtypes =='category')[0]
categorical_features_indices
# Out:
# array([ 1,  2,  4,  7, 12, 15, 19, 20, 23, 25, 32, 38, 43, 49, 84])

# %%
err=[]
y_pred_tot=[]

from sklearn.model_selection import KFold,StratifiedKFold,GroupKFold,GroupShuffleSplit
fold=StratifiedKFold(n_splits=10,shuffle=True,random_state=1994)
for train_index, test_index in fold.split(X[feat_cols],y):
    X_train, X_test = X[feat_cols].iloc[train_index], X[feat_cols].iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    m=CatBoostClassifier(n_estimators=3000,random_state=1994,eval_metric='AUC',learning_rate=0.05,random_strength=200,bagging_temperature=0.6,l2_leaf_reg=4,one_hot_max_size=10)
    m.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_test, y_test)], early_stopping_rounds=100,verbose=200,cat_features=categorical_features_indices)
    
    preds=m.predict_proba(X_test,ntree_end=m.best_iteration_)[:,-1]
    print("err: ",roc_auc_score(y_test,preds))
    err.append(roc_auc_score(y_test,preds))
    p = m.predict_proba(Xtest[feat_cols],ntree_end=m.best_iteration_)[:,-1]
    y_pred_tot.append(p)
# Out:
# 0:	test: 0.6455380	test1: 0.6247227	best: 0.6247227 (0)	total: 129ms	remaining: 6m 27s
# 200:	test: 0.8796224	test1: 0.8205381	best: 0.8205426 (199)	total: 28.7s	remaining: 6m 39s
# 400:	test: 0.8863090	test1: 0.9072728	best: 0.9073317 (399)	total: 58.3s	remaining: 6m 17s
# 600:	test: 0.8878275	test1: 0.9169785	best: 0.9169827 (599)	total: 1m 30s	remaining: 6m 3s
# 800:	test: 0.8897693	test1: 0.9186059	best: 0.9186103 (799)	total: 2m 3s	remaining: 5m 39s
# 1000:	test: 0.8896886	test1: 0.9198569	best: 0.9199111 (999)	total: 2m 36s	remaining: 5m 12s
# 1200:	test: 0.8905508	test1: 0.9199977	best: 0.9201125 (1114)	total: 3m 9s	remaining: 4m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9201124835
# bestIteration = 1114
#
# Shrink model to first 1115 iterations.
# err:  0.920100626150264
# 0:	test: 0.6469563	test1: 0.6323113	best: 0.6323113 (0)	total: 116ms	remaining: 5m 47s
# 200:	test: 0.8827627	test1: 0.8191795	best: 0.8193017 (198)	total: 28.9s	remaining: 6m 41s
# 400:	test: 0.8856330	test1: 0.9096789	best: 0.9096789 (400)	total: 59.6s	remaining: 6m 26s
# 600:	test: 0.8932117	test1: 0.9149383	best: 0.9149383 (600)	total: 1m 32s	remaining: 6m 8s
# 800:	test: 0.8960087	test1: 0.9180756	best: 0.9180999 (799)	total: 2m 4s	remaining: 5m 42s
# 1000:	test: 0.8977881	test1: 0.9193631	best: 0.9193716 (998)	total: 2m 37s	remaining: 5m 15s
# 1200:	test: 0.8995903	test1: 0.9201059	best: 0.9201625 (1174)	total: 3m 10s	remaining: 4m 45s
# 1400:	test: 0.8982136	test1: 0.9206236	best: 0.9206579 (1398)	total: 3m 43s	remaining: 4m 15s
# 1600:	test: 0.8988788	test1: 0.9210733	best: 0.9211655 (1585)	total: 4m 16s	remaining: 3m 44s
# 1800:	test: 0.8976423	test1: 0.9215487	best: 0.9216400 (1776)	total: 4m 49s	remaining: 3m 12s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9216399581
# bestIteration = 1776
#
# Shrink model to first 1777 iterations.
# err:  0.9216340294416819
# 0:	test: 0.5026634	test1: 0.4950072	best: 0.4950072 (0)	total: 279ms	remaining: 13m 57s
# 200:	test: 0.8804503	test1: 0.8059401	best: 0.8060134 (192)	total: 28.7s	remaining: 6m 39s
# 400:	test: 0.8929517	test1: 0.9059515	best: 0.9059515 (400)	total: 58.2s	remaining: 6m 17s
# 600:	test: 0.8947025	test1: 0.9147166	best: 0.9147166 (600)	total: 1m 30s	remaining: 6m 1s
# 800:	test: 0.8968897	test1: 0.9177086	best: 0.9177370 (794)	total: 2m 3s	remaining: 5m 38s
# 1000:	test: 0.9003841	test1: 0.9182511	best: 0.9183856 (962)	total: 2m 35s	remaining: 5m 11s
# 1200:	test: 0.9017518	test1: 0.9186030	best: 0.9188027 (1128)	total: 3m 8s	remaining: 4m 42s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9188026599
# bestIteration = 1128
#
# Shrink model to first 1129 iterations.
# err:  0.9187941834641531
# 0:	test: 0.5030684	test1: 0.5124610	best: 0.5124610 (0)	total: 179ms	remaining: 8m 57s
# 200:	test: 0.8832424	test1: 0.8010646	best: 0.8010648 (199)	total: 27.8s	remaining: 6m 27s
# 400:	test: 0.8842752	test1: 0.9027138	best: 0.9027138 (400)	total: 58.4s	remaining: 6m 18s
# 600:	test: 0.8871236	test1: 0.9124355	best: 0.9124355 (600)	total: 1m 30s	remaining: 6m 2s
# 800:	test: 0.8912960	test1: 0.9146113	best: 0.9146157 (797)	total: 2m 3s	remaining: 5m 39s
# 1000:	test: 0.8927173	test1: 0.9162336	best: 0.9163058 (995)	total: 2m 36s	remaining: 5m 12s
# 1200:	test: 0.8947553	test1: 0.9180658	best: 0.9180997 (1194)	total: 3m 9s	remaining: 4m 44s
# 1400:	test: 0.8954181	test1: 0.9187387	best: 0.9187590 (1395)	total: 3m 42s	remaining: 4m 14s
# 1600:	test: 0.8943786	test1: 0.9193821	best: 0.9194488 (1596)	total: 4m 16s	remaining: 3m 43s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.919719282
# bestIteration = 1662
#
# Shrink model to first 1663 iterations.
# err:  0.9196449429187987
# 0:	test: 0.5023901	test1: 0.4966438	best: 0.4966438 (0)	total: 176ms	remaining: 8m 47s
# 200:	test: 0.8692442	test1: 0.8092532	best: 0.8092532 (200)	total: 28.7s	remaining: 6m 39s
# 400:	test: 0.8847265	test1: 0.8989209	best: 0.8989209 (400)	total: 59.6s	remaining: 6m 26s
# 600:	test: 0.8896191	test1: 0.9083310	best: 0.9083723 (598)	total: 1m 31s	remaining: 6m 6s
# 800:	test: 0.8911453	test1: 0.9116574	best: 0.9116667 (799)	total: 2m 6s	remaining: 5m 47s
# 1000:	test: 0.8939528	test1: 0.9127255	best: 0.9127513 (998)	total: 2m 42s	remaining: 5m 25s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9127928267
# bestIteration = 1011
#
# Shrink model to first 1012 iterations.
# err:  0.9127727064111858
# 0:	test: 0.5044017	test1: 0.4973714	best: 0.4973714 (0)	total: 170ms	remaining: 8m 30s
# 200:	test: 0.8789250	test1: 0.8220470	best: 0.8226797 (177)	total: 28.2s	remaining: 6m 32s
# 400:	test: 0.8848641	test1: 0.9097686	best: 0.9098250 (399)	total: 59.5s	remaining: 6m 25s
# 600:	test: 0.8885121	test1: 0.9186514	best: 0.9186953 (595)	total: 1m 31s	remaining: 6m 6s
# 800:	test: 0.8918755	test1: 0.9208119	best: 0.9208505 (798)	total: 2m 4s	remaining: 5m 41s
# 1000:	test: 0.8950308	test1: 0.9218715	best: 0.9219166 (995)	total: 2m 39s	remaining: 5m 18s
# 1200:	test: 0.8961365	test1: 0.9230353	best: 0.9230643 (1196)	total: 3m 12s	remaining: 4m 48s
# 1400:	test: 0.8920119	test1: 0.9236468	best: 0.9236965 (1383)	total: 3m 45s	remaining: 4m 17s
# 1600:	test: 0.8932355	test1: 0.9239818	best: 0.9240699 (1524)	total: 4m 18s	remaining: 3m 46s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9240699194
# bestIteration = 1524
#
# Shrink model to first 1525 iterations.
# err:  0.9239777897652218
# 0:	test: 0.5037120	test1: 0.4996950	best: 0.4996950 (0)	total: 138ms	remaining: 6m 53s
# 200:	test: 0.8741677	test1: 0.8023245	best: 0.8023245 (200)	total: 28.7s	remaining: 6m 40s
# 400:	test: 0.8914132	test1: 0.8999760	best: 0.8999760 (400)	total: 1m	remaining: 6m 29s
# 600:	test: 0.8938835	test1: 0.9107334	best: 0.9107857 (599)	total: 1m 33s	remaining: 6m 12s
# 800:	test: 0.8963474	test1: 0.9129224	best: 0.9129224 (800)	total: 2m 6s	remaining: 5m 45s
# 1000:	test: 0.8968951	test1: 0.9136601	best: 0.9136794 (998)	total: 2m 39s	remaining: 5m 18s
# 1200:	test: 0.8977243	test1: 0.9140661	best: 0.9140661 (1200)	total: 3m 12s	remaining: 4m 48s
# 1400:	test: 0.8994890	test1: 0.9145827	best: 0.9145850 (1399)	total: 3m 46s	remaining: 4m 18s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9146364786
# bestIteration = 1416
#
# Shrink model to first 1417 iterations.
# err:  0.9146129696944282
# 0:	test: 0.5036787	test1: 0.5027210	best: 0.5027210 (0)	total: 173ms	remaining: 8m 39s
# 200:	test: 0.8964820	test1: 0.8251660	best: 0.8252477 (198)	total: 26.8s	remaining: 6m 12s
# 400:	test: 0.8911943	test1: 0.9046459	best: 0.9046459 (400)	total: 56.1s	remaining: 6m 3s
# 600:	test: 0.8932630	test1: 0.9122771	best: 0.9124506 (574)	total: 1m 28s	remaining: 5m 54s
# 800:	test: 0.8934339	test1: 0.9149567	best: 0.9149770 (796)	total: 2m 1s	remaining: 5m 34s
# 1000:	test: 0.8946940	test1: 0.9159504	best: 0.9160358 (972)	total: 2m 34s	remaining: 5m 9s
# 1200:	test: 0.8946059	test1: 0.9165121	best: 0.9166570 (1176)	total: 3m 7s	remaining: 4m 41s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9166569772
# bestIteration = 1176
#
# Shrink model to first 1177 iterations.
# err:  0.9166389748236141
# 0:	test: 0.5034970	test1: 0.4971498	best: 0.4971498 (0)	total: 175ms	remaining: 8m 44s
# 200:	test: 0.8780572	test1: 0.8145360	best: 0.8146668 (188)	total: 28s	remaining: 6m 29s
# 400:	test: 0.8899758	test1: 0.9111690	best: 0.9111690 (400)	total: 57.7s	remaining: 6m 14s
# 600:	test: 0.8934140	test1: 0.9191233	best: 0.9191233 (600)	total: 1m 30s	remaining: 5m 59s
# 800:	test: 0.8964760	test1: 0.9215771	best: 0.9216068 (799)	total: 2m 3s	remaining: 5m 37s
# 1000:	test: 0.8984932	test1: 0.9228104	best: 0.9228623 (993)	total: 2m 36s	remaining: 5m 11s
# 1200:	test: 0.8995939	test1: 0.9234822	best: 0.9235004 (1154)	total: 3m 9s	remaining: 4m 43s
# 1400:	test: 0.9013228	test1: 0.9244776	best: 0.9246983 (1379)	total: 3m 42s	remaining: 4m 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9246983072
# bestIteration = 1379
#
# Shrink model to first 1380 iterations.
# err:  0.9246923769809728
# 0:	test: 0.5040529	test1: 0.4994915	best: 0.4994915 (0)	total: 231ms	remaining: 11m 32s
# 200:	test: 0.8821987	test1: 0.8188259	best: 0.8188259 (200)	total: 28.4s	remaining: 6m 35s
# 400:	test: 0.8944471	test1: 0.9042180	best: 0.9042180 (400)	total: 58.6s	remaining: 6m 20s
# 600:	test: 0.8978172	test1: 0.9132545	best: 0.9132545 (600)	total: 1m 31s	remaining: 6m 4s
# 800:	test: 0.9004431	test1: 0.9153938	best: 0.9154063 (798)	total: 2m 4s	remaining: 5m 42s
# 1000:	test: 0.9004910	test1: 0.9166936	best: 0.9167961 (946)	total: 2m 38s	remaining: 5m 15s
# 1200:	test: 0.9019537	test1: 0.9176736	best: 0.9178305 (1165)	total: 3m 11s	remaining: 4m 47s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.9178910909
# bestIteration = 1240
#
# Shrink model to first 1241 iterations.
# err:  0.9178805012784842

# %%
err1=[]
y_pred_tot1=[]

from sklearn.model_selection import KFold,StratifiedKFold,GroupKFold,GroupShuffleSplit
fold=StratifiedKFold(n_splits=10,shuffle=True,random_state=1994)
for train_index, test_index in fold.split(X[feat_cols1],y):
    X_train, X_test = X[feat_cols1].iloc[train_index], X[feat_cols1].iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    m=LGBMClassifier(n_estimators=5000,random_state=1994,learning_rate=0.05,colsample_bytree=0.5,reg_alpha=4,min_split_gain=0.2,min_child_samples=2,bagging_fraction=0.9)
    m.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_test, y_test)],eval_metric='AUC', early_stopping_rounds=50,verbose=200)
    
    preds=m.predict_proba(X_test,num_iteration=m.best_iteration_)[:,-1]
    print("err: ",roc_auc_score(y_test,preds))
    err1.append(roc_auc_score(y_test,preds))
    p = m.predict_proba(Xtest[feat_cols1],num_iteration=m.best_iteration_)[:,-1]
    y_pred_tot1.append(p)
# Out:
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [64]	training's auc: 0.884792	training's binary_logloss: 0.368421	valid_1's auc: 0.833136	valid_1's binary_logloss: 0.414075
# err:  0.8331357822050687
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [64]	training's auc: 0.884989	training's binary_logloss: 0.368548	valid_1's auc: 0.843268	valid_1's binary_logloss: 0.404081
# err:  0.8432675295395047
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [54]	training's auc: 0.879416	training's binary_logloss: 0.377513	valid_1's auc: 0.836603	valid_1's binary_logloss: 0.411658
# err:  0.8366028743621475
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [73]	training's auc: 0.890077	training's binary_logloss: 0.360109	valid_1's auc: 0.831472	valid_1's binary_logloss: 0.413244
# err:  0.8314716790279242
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [74]	training's auc: 0.890947	training's binary_logloss: 0.359152	valid_1's auc: 0.831896	valid_1's binary_logloss: 0.41339
# err:  0.8318963225867804
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [69]	training's auc: 0.887308	training's binary_logloss: 0.364608	valid_1's auc: 0.845662	valid_1's binary_logloss: 0.402417
# err:  0.8456618689357247
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	training's auc: 0.888264	training's binary_logloss: 0.362899	valid_1's auc: 0.832967	valid_1's binary_logloss: 0.412536
# err:  0.8329665090720173
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [67]	training's auc: 0.886963	training's binary_logloss: 0.365415	valid_1's auc: 0.836376	valid_1's binary_logloss: 0.409258
# err:  0.8363759414961898
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [69]	training's auc: 0.886416	training's binary_logloss: 0.365469	valid_1's auc: 0.846024	valid_1's binary_logloss: 0.400606
# err:  0.8460238219741711
# [LightGBM] [Warning] bagging_fraction is set=0.9, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [67]	training's auc: 0.886374	training's binary_logloss: 0.366022	valid_1's auc: 0.837994	valid_1's binary_logloss: 0.408161
# err:  0.8379935051773687

# %%
# err11=[]
# y_pred_tot11=[]

# from sklearn.model_selection import KFold,StratifiedKFold,GroupKFold,GroupShuffleSplit
# fold=StratifiedKFold(n_splits=5,shuffle=True,random_state=2021)
# for train_index, test_index in fold.split(X[feat_cols],y):
#     X_train, X_test = X[feat_cols].iloc[train_index], X[feat_cols].iloc[test_index]
#     y_train, y_test = y[train_index], y[test_index]
#     m=LGBMClassifier(n_estimators=5000,random_state=2021,learning_rate=0.05,colsample_bytree=0.5,reg_alpha=4,min_split_gain=0.2,min_child_samples=2,bagging_fraction=0.9)
#     m.fit(X_train,y_train,eval_set=[(X_train,y_train),(X_test, y_test)],eval_metric='AUC', early_stopping_rounds=50,verbose=200)
    
#     preds=m.predict_proba(X_test,num_iteration=m.best_iteration_)[:,-1]
#     print("err: ",roc_auc_score(y_test,preds))
#     err11.append(roc_auc_score(y_test,preds))
#     p = m.predict_proba(Xtest[feat_cols],num_iteration=m.best_iteration_)[:,-1]
#     y_pred_tot11.append(p)

# %%
np.mean(y_pred_tot1,0)
# Out:
# array([0.12690802, 0.18604997, 0.25869438, ..., 0.03002634, 0.6841462 ,
#        0.19779674])

# %%
np.mean(err1),np.mean(err)
# Out:
# (0.8375395834376897, 0.9190749100928806)

# %%
dftest['Response']=np.mean(y_pred_tot1,0)

dftest[['ID','Response']].to_csv('AV-frk1-job-lgb-sub4.csv',index=False)

# %%
dftest['Response']=np.mean(y_pred_tot,0)

dftest[['ID','Response']].to_csv('AV-frk1-job-cb-sub4.csv',index=False)

# %%
dftest['Response']=np.mean(y_pred_tot,0)*0.85+np.mean(y_pred_tot1,0)*0.15

dftest[['ID','Response']].to_csv('AV-frk1-job-stack-sub4.csv',index=False)
